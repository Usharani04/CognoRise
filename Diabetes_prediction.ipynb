# %% [markdown]
# #IMPORTING THE PACKAGES

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # LOAD THE DATA

# %%
df=pd.read_csv("/content/diabetes.csv")
df
# Out:
#       Age  Gender   BMI  SBP  DBP   FPG  Chol   Tri   HDL   LDL   ALT   BUN  \
# 0      26       1  20.1  119   81  5.80  4.36  0.86  0.90  2.43  12.0  5.40
# 1      40       1  17.7   97   54  4.60  3.70  1.02  1.50  2.04   9.2  3.70
# 2      40       2  19.7   85   53  5.30  5.87  1.29  1.75  3.37  10.1  4.10
# 3      43       1  23.1  111   71  4.50  4.05  0.74  1.27  2.60  36.5  4.38
# 4      36       1  26.5  130   82  5.54  6.69  3.49  0.91  3.64  69.3  3.86
# ...   ...     ...   ...  ...  ...   ...   ...   ...   ...   ...   ...   ...
# 4298   54       1  23.4  126   75  6.82  5.00  1.50  1.24  2.98   8.0  3.50
# 4299   50       2  22.3  115   84  5.32  4.37  2.09  1.37  2.29  21.2  4.40
# 4300   67       1  24.6  138   81  4.85  3.89  1.38  1.14  2.17  18.1  4.73
# 4301   60       2  29.0  101   60  6.70  5.91  1.29  1.73  2.85  18.9  7.33
# 4302   37       1  34.3  120   71  4.97  5.42  2.66  1.08  2.87  81.0  4.61
#
# ...

# %%
df.head()
# Out:
#    Age  Gender   BMI  SBP  DBP   FPG  Chol   Tri   HDL   LDL   ALT   BUN  \
# 0   26       1  20.1  119   81  5.80  4.36  0.86  0.90  2.43  12.0  5.40
# 1   40       1  17.7   97   54  4.60  3.70  1.02  1.50  2.04   9.2  3.70
# 2   40       2  19.7   85   53  5.30  5.87  1.29  1.75  3.37  10.1  4.10
# 3   43       1  23.1  111   71  4.50  4.05  0.74  1.27  2.60  36.5  4.38
# 4   36       1  26.5  130   82  5.54  6.69  3.49  0.91  3.64  69.3  3.86
#
#     CCR  FFPG  smoking  drinking  family_histroy  Diabetes
# 0  63.8  5.40      3.0       3.0               0         0
# 1  70.3  4.10      1.0       1.0               0         0
# 2  61.1  4.85      3.0       3.0               0         0
# 3  73.4  5.30      2.0       3.0               0         0
# 4  67.5  5.53      3.0       3.0               0         0

# %%
df.tail()
# Out:
#       Age  Gender   BMI  SBP  DBP   FPG  Chol   Tri   HDL   LDL   ALT   BUN  \
# 4298   54       1  23.4  126   75  6.82  5.00  1.50  1.24  2.98   8.0  3.50
# 4299   50       2  22.3  115   84  5.32  4.37  2.09  1.37  2.29  21.2  4.40
# 4300   67       1  24.6  138   81  4.85  3.89  1.38  1.14  2.17  18.1  4.73
# 4301   60       2  29.0  101   60  6.70  5.91  1.29  1.73  2.85  18.9  7.33
# 4302   37       1  34.3  120   71  4.97  5.42  2.66  1.08  2.87  81.0  4.61
#
#        CCR  FFPG   smoking  drinking  family_histroy  Diabetes
# 4298  77.0  6.70  1.000000  3.000000               0         1
# 4299  47.3  6.55  4.860753  4.860753               0         1
# 4300  70.6  6.80  3.000000  3.000000               0         1
# 4301  50.2  7.00  3.000000  3.000000               0         1
# 4302  75.5  8.20  1.000000  2.000000               0         1

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'BMI', 'SBP', 'DBP', 'FPG', 'Chol', 'Tri', 'HDL',
#        'LDL', 'ALT', 'BUN', 'CCR', 'FFPG', 'smoking', 'drinking',
#        'family_histroy', 'Diabetes'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                 int64
# Gender              int64
# BMI               float64
# SBP                 int64
# DBP                 int64
# FPG               float64
# Chol              float64
# Tri               float64
# HDL               float64
# LDL               float64
# ALT               float64
# BUN               float64
# CCR               float64
# FFPG              float64
# smoking           float64
# drinking          float64
# family_histroy      int64
# Diabetes            int64
# dtype: object

# %%
df.describe()
# Out:
#                Age       Gender          BMI          SBP          DBP  \
# count  4303.000000  4303.000000  4303.000000  4303.000000  4303.000000
# mean     48.085057     1.351615    24.123923   123.219382    76.360446
# std      14.686155     0.477530     3.397294    17.513858    11.004056
# min      22.000000     1.000000    15.600000    72.000000    45.000000
# 25%      35.000000     1.000000    21.700000   111.000000    69.000000
# 50%      46.000000     1.000000    24.000000   122.000000    76.000000
# 75%      59.000000     2.000000    26.300000   134.000000    83.000000
# max      93.000000     2.000000    45.800000   200.000000   134.000000
#
#                FPG         Chol          Tri          HDL          LDL  \
# count  4303.000000  4303.000000  4303.000000  4303.000000  4303.000000
# mean      5.226368     4.860753     1.588476     1.666765     2.976220
# std       0.781089     0.925377     1.260003     1.079377     0.892196
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4303 entries, 0 to 4302
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             4303 non-null   int64
#  1   Gender          4303 non-null   int64
#  2   BMI             4303 non-null   float64
#  3   SBP             4303 non-null   int64
#  4   DBP             4303 non-null   int64
#  5   FPG             4303 non-null   float64
#  6   Chol            4303 non-null   float64
#  7   Tri             4303 non-null   float64
#  8   HDL             4303 non-null   float64
#  9   LDL             4303 non-null   float64
#  10  ALT             4303 non-null   float64
#  11  BUN             4303 non-null   float64
#  12  CCR             4303 non-null   float64
#  13  FFPG            4303 non-null   float64
#  14  smoking         4303 non-null   float64
#  15  drinking        4303 non-null   float64
#  16  family_histroy  4303 non-null   int64
# ...

# %%
df.shape
# Out:
# (4303, 18)

# %% [markdown]
# #CHECKING FOR DUPLICATE VALUES

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4298    False
# 4299    False
# 4300    False
# 4301    False
# 4302    False
# Length: 4303, dtype: bool

# %% [markdown]
# #CHECKING FOR UNIQUE VALUES

# %%
df.nunique(axis=0)
# Out:
# Age                70
# Gender              2
# BMI               275
# SBP               111
# DBP                75
# FPG               361
# Chol              486
# Tri               478
# HDL               188
# LDL               384
# ALT               680
# BUN               576
# CCR               700
# FFPG              479
# smoking             4
# drinking            4
# family_histroy      2
# Diabetes            2
# dtype: int64

# %% [markdown]
# #ANALYSING THE MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Age               0
# Gender            0
# BMI               0
# SBP               0
# DBP               0
# FPG               0
# Chol              0
# Tri               0
# HDL               0
# LDL               0
# ALT               0
# BUN               0
# CCR               0
# FFPG              0
# smoking           0
# drinking          0
# family_histroy    0
# Diabetes          0
# dtype: int64

# %%
df.groupby('Diabetes').size()
# Out:
# Diabetes
# 0    3000
# 1    1303
# dtype: int64

# %% [markdown]
# #DATA VISUALIZATION

# %%
plt.figure(figsize=(5, 6))
sns.countplot(data=df, x='Diabetes', palette='Set2')
plt.xlabel('Diabetes')
plt.ylabel('Count')
plt.title('Bar Chart of Diabetes')
plt.show()
# Out:
# <ipython-input-39-71c55ffd6453>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Diabetes', palette='Set2')

# %%
df.hist(figsize=(16,12),color='purple');

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1,3,3)
sns.boxplot(x=df.Diabetes,y=df.HDL,palette='Set1')
plt.title("Boxplot for HDL by outcome")
# Out:
# <ipython-input-54-67d8dcf02461>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df.Diabetes,y=df.HDL,palette='Set1')
# Text(0.5, 1.0, 'Boxplot for HDL by outcome')

# %%
sns.lmplot(x='BMI',y='DBP',data=df,fit_reg=False,hue='Diabetes')

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'BMI', 'SBP', 'DBP', 'FPG', 'Chol', 'Tri', 'HDL',
#        'LDL', 'ALT', 'BUN', 'CCR', 'FFPG', 'smoking', 'drinking',
#        'family_histroy', 'Diabetes'],
#       dtype='object')

# %%
sns.pairplot(df, vars=[ 'BMI', 'SBP', 'DBP', 'Chol', 'Tri', 'HDL',
       'LDL', 'ALT'],hue="Diabetes")
plt.title("Pairplot of Variables by Outcome")
# Out:
# Text(0.5, 1.0, 'Pairplot of Variables by Outcome')

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Chol'], df['Tri'], alpha=0.5,color='red')
plt.xlabel('Cholesterol')
plt.ylabel('Triglyceride')
plt.title('Scatter Plot: Cholesterol vs. Triglyceride')
plt.grid(True)
plt.show()

# %%
pd.plotting.scatter_matrix(df[['BMI', 'DBP', 'HDL', 'ALT','CCR']], alpha=0.8, figsize=(10, 10), diagonal='hist',color='pink')
plt.suptitle('Scatterplot Matrix', y=1.02)
plt.show()

# %%
cor = df.corr()
cor
# Out:
#                      Age    Gender       BMI       SBP       DBP       FPG  \
# Age             1.000000  0.004783  0.232346  0.437992  0.230389  0.370798
# Gender          0.004783  1.000000 -0.252456 -0.125792 -0.186603 -0.073297
# BMI             0.232346 -0.252456  1.000000  0.328772  0.318889  0.270508
# SBP             0.437992 -0.125792  0.328772  1.000000  0.651806  0.263391
# DBP             0.230389 -0.186603  0.318889  0.651806  1.000000  0.178995
# FPG             0.370798 -0.073297  0.270508  0.263391  0.178995  1.000000
# Chol            0.242679  0.055566  0.173834  0.164950  0.141619  0.163499
# Tri             0.163353 -0.155444  0.315455  0.196480  0.194973  0.212294
# HDL             0.213133  0.072716  0.047260  0.089887  0.048761  0.201780
# LDL             0.295938  0.001364  0.201447  0.167468  0.146217  0.239304
# ALT            -0.036210 -0.235779  0.343488  0.111913  0.158603  0.113730
# ...

# %% [markdown]
# #HEAT MAP

# %%
sns.heatmap(cor)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'BMI', 'SBP', 'DBP', 'FPG', 'Chol', 'Tri', 'HDL',
#        'LDL', 'ALT', 'BUN', 'CCR', 'FFPG', 'smoking', 'drinking',
#        'family_histroy', 'Diabetes'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

x=df[['Age', 'Gender', 'BMI', 'SBP', 'DBP', 'FPG', 'Chol', 'Tri', 'HDL',
       'LDL', 'ALT', 'BUN', 'CCR', 'FFPG', 'smoking', 'drinking',
       'family_histroy']]
y=df['Diabetes']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
x_train
# Out:
#       Age  Gender    BMI  SBP  DBP   FPG  Chol   Tri       HDL       LDL  \
# 2732   45       1  26.30  133   73  4.90  4.67  2.23  1.200000  2.430000
# 1247   40       2  19.10   92   59  4.08  2.93  0.31  1.140000  1.740000
# 144    33       2  24.30  133   76  4.86  6.42  1.39  1.490000  4.470000
# 3046   70       1  22.68  111   63  5.78  5.15  1.36  4.860753  4.860753
# 2691   41       1  30.60  103   61  5.20  4.06  0.63  1.320000  2.410000
# ...   ...     ...    ...  ...  ...   ...   ...   ...       ...       ...
# 3655   30       1  31.20  116   78  4.33  5.13  2.20  1.070000  3.030000
# 2462   50       1  23.80  111   87  5.17  6.30  1.76  1.520000  3.800000
# 1739   35       2  23.90  116   74  3.82  4.17  3.10  1.000000  2.230000
# 3400   61       1  27.70  103   79  5.37  5.93  1.30  1.060000  4.040000
# 2036   29       1  21.30  110   66  4.41  4.60  0.60  1.690000  2.040000
#
#        ALT   BUN   CCR  FFPG   smoking  drinking  family_histroy
# ...

# %%
x_test
# Out:
#       Age  Gender   BMI  SBP  DBP   FPG  Chol   Tri   HDL   LDL   ALT   BUN  \
# 545    47       2  20.6   94   73  5.23  4.13  1.32  1.66  2.43  12.2  2.41
# 3759   61       1  23.5  120   91  6.42  4.54  0.65  1.60  2.52  25.1  5.04
# 2390   52       2  20.4  136   83  3.81  4.35  0.83  1.64  2.51  11.2  4.35
# 1126   35       1  24.3  145   98  5.37  5.14  1.79  1.28  2.85  47.0  4.42
# 3850   61       1  25.4  119   76  6.70  4.34  2.33  1.41  2.08  24.5  4.79
# ...   ...     ...   ...  ...  ...   ...   ...   ...   ...   ...   ...   ...
# 43     52       1  21.5  108   70  4.62  6.04  1.14  1.43  3.50  20.0  5.90
# 1793   43       2  21.8   94   61  5.10  4.42  0.64  1.61  2.77  11.9  5.20
# 4012   45       2  20.9   83   53  4.18  5.34  0.41  1.25  2.99  15.7  4.13
# 1645   35       1  25.1  154   87  4.05  4.60  1.00  1.69  2.33  57.0  5.21
# 2393   34       2  18.4   92   56  4.97  4.68  0.42  1.86  2.61  10.7  3.90
#
#        CCR  FFPG   smoking  drinking  family_histroy
# ...

# %%
y_train
# Out:
# 2732    0
# 1247    0
# 144     0
# 3046    1
# 2691    0
#        ..
# 3655    1
# 2462    0
# 1739    0
# 3400    1
# 2036    0
# Name: Diabetes, Length: 3442, dtype: int64

# %%
y_test
# Out:
# 545     0
# 3759    1
# 2390    0
# 1126    0
# 3850    1
#        ..
# 43      0
# 1793    0
# 4012    1
# 1645    0
# 2393    0
# Name: Diabetes, Length: 861, dtype: int64

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
base_classifier = DecisionTreeClassifier(max_depth=1)
adaboost_classifier = AdaBoostClassifier(base_classifier, n_estimators=50, random_state=0)
adaboost_classifier.fit(x_train, y_train)
y_pred = adaboost_classifier.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9488966318234611

# %%
print("Accuracy on testing data is ", adaboost_classifier.score(x_test,y_test))
print("Accuracy on training data is ", adaboost_classifier.score(x_train,y_train))
# Out:
# Accuracy on testing data is  0.9488966318234611
# Accuracy on training data is  0.9628123184195235

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[616  16]
#  [ 28 201]]

# %%
print(classification_report( y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97       632
#            1       0.93      0.88      0.90       229
#
#     accuracy                           0.95       861
#    macro avg       0.94      0.93      0.93       861
# weighted avg       0.95      0.95      0.95       861

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
linear_regression_model = LinearRegression()
linear_regression_model.fit(x_train, y_train)
y_pred = linear_regression_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 0.05844743368188266

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np
rfc= RandomForestRegressor(n_estimators = 51, random_state = 1)
model = rfc.fit(x_train, y_train)
np.sqrt(mean_squared_error(y_train, model.predict(x_train)))
r2_score(y_train, model.predict(x_train))
# Out:
# 0.9771733453094121

# %% [markdown]
# #PREDICTIVE SYSTEM

# %%
df.head()
# Out:
#    Age  Gender   BMI  SBP  DBP   FPG  Chol   Tri   HDL   LDL   ALT   BUN  \
# 0   26       1  20.1  119   81  5.80  4.36  0.86  0.90  2.43  12.0  5.40
# 1   40       1  17.7   97   54  4.60  3.70  1.02  1.50  2.04   9.2  3.70
# 2   40       2  19.7   85   53  5.30  5.87  1.29  1.75  3.37  10.1  4.10
# 3   43       1  23.1  111   71  4.50  4.05  0.74  1.27  2.60  36.5  4.38
# 4   36       1  26.5  130   82  5.54  6.69  3.49  0.91  3.64  69.3  3.86
#
#     CCR  FFPG  smoking  drinking  family_histroy  Diabetes
# 0  63.8  5.40      3.0       3.0               0         0
# 1  70.3  4.10      1.0       1.0               0         0
# 2  61.1  4.85      3.0       3.0               0         0
# 3  73.4  5.30      2.0       3.0               0         0
# 4  67.5  5.53      3.0       3.0               0         0

# %%
input_data = (60,2,22.1,146,74,6.3,3.3,1.35,1.24,1.81,14.2,4.5,61.4,5.8,4.86,4.86,0)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = adaboost_classifier.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [1]
# The person is diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
